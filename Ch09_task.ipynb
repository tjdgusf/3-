# %% [markdown]
# 해설:
# sep 옵션은 요소 사이의 경계를 표시함.
#
# [문제2]
#
# 두 개의 값을 입력 받아 실수로 x와 y 변수에 저장하는 코드를 골라 주세요
#
# x, y = input('실수를 입력하세요: ')
# x, y = input('실수를 입력하세요: ').split()
# x = input('실수를 입력하세요'); y = input('실수를 입력하세요')
# x, y = map(float, input('실수를 입력하세요: ').split())
# 답변
#
# 답: 4
#
# 해설:
# map는 함수를 각각의 요소에 적용하여 map객체로 리턴하는 함수.
# split은 각 문자열을 나누어 리스트로 리턴하는 str의 메서드.
#
# [문제3]
#
#
# 아래와 같이 주어졌을때 실행 결과와 동일하게 출력되기 위해 1)과 2) 들어갈 코드를 작성해주세요
#
# month = 12
# day = 25
# hour = 12
# minute = 30
#
# print(month, day, 1)________)
# print(hour, minute, 2)_______)
#
# 실행 결과 : 1) 12.25, 2) 12:30
#
# 답변
#
# 답:
#
# sep = '.'
# sep = ':'
# Chapter10 : Python의 시퀀스 자료형 중 하나인 list에 대해 알아보고 문제를 해결해보자
# [문제1]
#
# 아래 리스트에 들어있는 값의 평균을 구하는 코드를 작성해주세요
#
# x = [34, 22, 10, 3, 55, 66]
#
# 답변
#
# 답:
# x = [34, 22, 10, 3, 55, 66]
# result = sum(x) / len(x)
# print(result)
#
# [문제2]
#
# 리스트 안에 있는 데이터를 오름차순으로 정렬하는 메소드를 모두 골라주세요
#
# upper()
# low()
# sort()
# hight()
# sorted()
# 답변
#
# 답: 3
#
# 해설:
# 1.문자열을 대문자로 리턴함
# 2.문자열을 소문자로 리턴
# 5.문자열을 정렬하여 값을 바꾸지 않고 리턴만 함.
#
# [문제3]
#
# 리스트 x가 있을 때 x.append(7)과 결과가 동일한 것을 모두 골라주세요
#
# x[-1:] = [7]
# x.insert(len(x), 7)
# x[0:] = 7
# x[len(x):] = 7
# x[len(x):] = [7]
# 답변
#
# 답: 2 5
#
# 해설:
# x = [....,x]
# 1.[7]요소를 리스트의 마지막과 바꿈
# 3.리스트 요소 모두를 7로 바꿈
# 4.False
#
# [문제4]
#
# 리스트의 모든 요소를 삭제하는 메서드를 골라주세요
#
# remove
# clean
# pop
# clear
# reverse
# 답변
#
# 답: 2
#
# 해설:
# 1.요소값 1개를 선택하여 삭제
# 2.??
# 3.요소를 1개를 빼내어 리턴
# 5.객체의 순서를 뒤집음
#
# [문제5]
#
# [3.1, 6.7, 4.4]가 들어있는 리스트의 값을 문자열로 변환 후 다시 리스트로 만들어 변수 x에 담는 코드를 골라주세요
#
# x = list(str, [3.1, 6.7, 4.4])
# x = map(str, [3.1, 6.7, 4.4])
# x = str([3.1, 6.7, 4.4])
# x = list(map(str, [3.1, 6.7, 4.4]))
# x = map(int, [3.1, 6.7, 4.4])
# 답변
#
# 답: 4
#
# 해설:
# 1.표현식이 잘못됨
# 2.언패킹된 map객체(이터러블)로 리턴
# 3.'[3.1, 6.7, 4.4]'리스트가 아닌 문자열 자체로 리턴
# 5.언패킹된 map 객체을 정수 형식으로 리턴
#
# Chapter11 : Python의 시퀀스 자료형 중 하나인 tuple에 대해 알아보고 문제를 해결해보자
# [문제1]
#
# tuple과 list의 차이점으로 올바른 것을 모두 골라주세요
#
# list만 인덱싱이 가능해 원하는 값을 인덱스로 추출할 수 있다.
# tuple은 불변이고 list는 가변이다.
# tuple은 소괄호( () )를 사용하고 리스트는 대괄호( [ ] )를 사용한다.
# 튜플은 입출력이 자주 발행하는 경우 사용하고 리스트는 입출력이 자주 발생하지 않는 상황에 사용한다
# 답변
#
# 답: 2 3
#
# [문제2]
#
# tuple a에 사용할 수 없는 코드를 골라주세요
# a = (20, 10, 15)
#
# print(a[:])
# a.pop()
# sum(a)
# a.count(20)
# 답변
#
# 답: 2
#
# 해설:
# 튜플은 불변이기 때문에 원본(객체)을 수정하는 작업을 할 수 없음.
#
# [문제3]
#
# 아래 코드를 실행시켰을 때 발생하는 상황과 원인을 간략히 설명해주세요
#
# 바구니 = ( "상추", "깻잎", "삼겹살")
# 바구니[1] = "고사리"
# 답변
#
# 답 : 리스트는 불변이므로 값을 수정하거나 추가하는 작업은 할 수 없음. 정 하고싶다면
# 바구니 = ( "상추", "깻잎", "삼겹살")
# 바구니 = tuple(list(바구니) + ["고사리"])
#
# Chapter12 : Python의 시퀀스 자료형 중 하나인 dict에 대해 알아보고 문제를 해결해보자
# [문제1]
#
# 딕셔너리 x에서 키에 해당하는 값을 모두 삭제하는 방법으로 옳은 것을 모두 골라주세요
#
# x = {'banana':3000, 'apple':1500, 'orange':2000}
#
# x.pop('apple')
# x.remove('python')
# del x['orange']
# x.popitem()
# 답변
#
# 답: 1 3 4
#
# 해설:
# remove 딕셔너리 자료형에 쓸 쑤 없음.
#
# [문제2]
#
# 딕셔너리의 메서드에 대한 설명으로 올바르지 않은 것을 모두 고르세요
#
# setdefault는 키만 지정하면 값은 0으로 저장한다.
# update는 딕셔너리에서 키의 value 값을 수정한다.
# keys는 딕셔너리의 키-값 쌍을 모두 가져온다.
# clear는 딕셔너리의 모든 키-값 쌍을 삭제한다.
# setdefault에 키와 값을 넣어 실행하면 기존 딕셔너리에 없는 키값일 경우 키-값 쌍을 추가한다.
# 답변
#
# 답: 1 3
#
# 해설:
# 1.값을 0이 아닌 None으로 저장
# 3.times
#
# [문제3]
#
# 평균 점수를 구하는 코드를 result 변수에 작성해주세요
#
# ozkim = { "국어" : 90, "'수학" : 80, "과학" : 82, "영어" : 72 }
# result =
# print(result)
# 답변
#
# 답:
# ozkim = { "국어" : 90, "'수학" : 80, "과학" : 82, "영어" : 72 }
# result = sum(ozkim.values()) / len(ozkim)
# print(result)
#
# [문제4]
#
# 상자 딕셔너리에 아래 데이터를 추가하는 코드를 작성해 주세요
#
# 상자 = {"아디다스": ["신발", "2개"],
#             "나이키": ["모자", "5개"],
#             "뉴발란스": ["가방", "1개"]}
# 입력할 데이터 : 칼하트 / 후드티 / 2벌
#
# 답변
#
# 상자 = {"아디다스": ["신발", "2개"],
# "나이키": ["모자", "5개"],
# "뉴발란스": ["가방", "1개"]}
# 상자['칼하트'] = ['후드티', '2벌']
# print(상자)

# %%
상자 = {"아디다스": ["신발", "2개"], 
            "나이키": ["모자", "5개"], 
            "뉴발란스": ["가방", "1개"]}
상자['칼하트'] = ['후드티', '2벌']
print (상자)
# Out:
# {'아디다스': ['신발', '2개'], '나이키': ['모자', '5개'], '뉴발란스': ['가방', '1개'], '칼하트': ['후드티', '2벌']}

# %% [markdown]
# [문제5]
#
# 아래 keys 변수와 vals 변수에 들어있는 값을 이용해 agency_dict라는 딕셔너리를 만드는 코드를 작성해주세요
#
# keys = ["뉴진스", "아이브", "에스파"]
# vals = ["하이브" , "스타쉽", "SM"]

# %%
keys = ["뉴진스", "아이브", "에스파"]
vals = ["하이브" , "스타쉽", "SM"]
agency_dict = dict(zip(keys, vals))
print(agency_dict)
# Out:
# {'뉴진스': '하이브', '아이브': '스타쉽', '에스파': 'SM'}

# %% [markdown]
# Chapter13 : Python의 시퀀스 자료형 중 하나인 set에 대해 알아보고 문제를 해결해보자
# [문제1]
#
# 세트 money의 결과로 올바른 것을 골라주세요
#
# money = { '만원', '만원', '오만원', '백원', '오만원', '십원' }
#
# { '백원', '십원' }
# {'만원', '백원', '십원', '오만원'}
# {'만원', '백원', '십원'}
# {'만원', '오만원'}
# 답변
#
# 답: 2
#
# 해설 :
# set자료형은 요소들의 순서를 무시하며, 중복을 허용하지 않는다.
#
# [문제2]
#
# 세트 x = {3, 6, 9} 그리고 y = {1, 2, 3}가 있을 때, 집합 연산의 결과로 잘못된 것을 모두 고르세요
#
# set.union(x, y)는 {1, 2, 3, 6, 9}
# x ^ y는 {1, 3, 6}
# x - y는 {6, 9}
# x & y는 { 3 }
# set.difference(y, x)는 { 2 }
# 답변
#
# 답 : 2 5
#
# 해설 :
# 2.대칭 차집합 {1,2,6,9}
# 5.{1,2}임
#
# [문제3]
#
# 과일 바구니 안에 두리안이 있는지 확인하기 위한 코드를 작성해 주세요
#
# 과일_바구니 = {'사과', '포도', '샤인머스켓', '두리안'}
#
# 답변
#
# 답: '두리안' in 과일_바구니
#
# [문제4]
#
# 메서드와 연산자의 기능이 잘못 짝지어진 것을 골라주세요
#
# set.intersection은 &와 같다.
# set.update는 |=와 같다.
# symmetric_difference_update는 -=와 같다.
# issuperset은 >와 같다.
# set.union은 |와 같다.
# 답변
#
# 답: 3 4
#
# 해설:
# 3.대칭_차집합으로 ^=과 같음
# 4.issuperset 은 >=과 같음
#
# [문제5]
#
# 세트를 만드는 방법으로 올바르지 않은 것을 골라주세요
#
# x = {1, 2, 3, 4, 5}
# x = { }
# x = set('hello')
# x = set(range(10))
# x = set()
# 답변
#
# 답: 2
#
# 해설:
# dict로 딕셔너리를 리턴함.
